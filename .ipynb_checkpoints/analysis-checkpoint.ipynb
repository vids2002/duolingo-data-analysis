# %%
# Import functions for analysis
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import matplotlib.pyplot as plt
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# # RAW DATA FILE

# %%
# Reading cvs file
df = pd.read_csv('duo.csv')

# %%
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (124, 39)
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"America/Lo...
# 2                                2025-03-18 15:50:56
# 3                                2025-03-18 20:17:44
# 4                                2025-03-18 20:26:23
#
#                                              EndDate                 Status  \
# 0                                           End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"America/Los_...  {"ImportId":"status"}
# 2                                2025-03-18 15:51:38         Survey Preview
# 3                                2025-03-18 20:17:57         Survey Preview
# 4                                2025-03-18 20:37:47         Survey Preview
#
#                   IPAddress                 Progress    Duration (in seconds)  \
# 0                IP Address                 Progress    Duration (in seconds)
# ...

# %% [markdown]
# # DATA CLEANING

# %%
# Removing unnecessary columns 
df_duo = df.copy()

columns_to_drop = [
    'StartDate', 'EndDate', 'Status', 'IPAddress', 'Progress',
    'Duration (in seconds)', 'Finished', 'RecordedDate', 'ResponseId',
    'RecipientLastName', 'RecipientFirstName', 'RecipientEmail',
    'ExternalReference', 'LocationLatitude', 'LocationLongitude',
    'DistributionChannel', 'UserLanguage', 'Q18.1'
]

df_duo = df_duo.drop(columns = [col for col in columns_to_drop if col in df_duo.columns])

# %%
# Dropped first 4 rows (metadata + test runs) on [DATE]. 
# This cell has been disabled to avoid accidentally deleting real data.
#df_duo = df_duo.iloc[4:].reset_index(drop=True)

# %%
# Rename column names
df_duo = df_duo.rename(columns={
    'Q1': 'uses_duo',
    'Q2': 'free_or_premium',
    'Q2.1': 'age',
    'Q3': 'fluent_lang_num',
    'Q4': 'other_lang_learning_apps',
    'Q5': 'reason',
    'Q5_5_TEXT': 'reason_other',
    'QID6': 'frequency',
    'Q9': 'target_language(s)',
    'Q9_5_TEXT': 'target_language(s)_other',
    'Q10': 'consistency',
    'Q11': 'adapt_individual',
    'Q12': 'adapt_mistakes',
    'Q13': 'best_feature',
    'Q13_5_TEXT': 'best_feature_other',
    'Q17': 'adapt_effectiveness',
    'Q18': 'pain_point',
    'Q18_5_TEXT': 'pain_point_other',
    'Q19': 'potential_improvement',
    'Q19_5_TEXT': 'potential_improvement_other',
    'Q21': 'UI_improvements'
})

# %% [markdown]
# ### OUR CLEAN DATA SET

# %%
df_duo.head()
# Out:
#   uses_duo free_or_premium age fluent_lang_num other_lang_learning_apps  \
# 0      Yes    Free Version  22               2                       No
# 1      Yes    Free Version  20               2                       No
# 2      Yes    Free Version  21               2                       No
# 3      Yes    Free Version  15               2                       No
# 4      Yes    Free Version  20               2                       No
#
#                                               reason reason_other  \
# 0                    Travel,Personal interests/Hobby          NaN
# 1                           Personal interests/Hobby          NaN
# 2  Academic Purposes,Travel,Personal interests/Ho...          NaN
# 3                           Personal interests/Hobby          NaN
# 4                    Travel,Personal interests/Hobby          NaN
#
#                                           frequency target_language(s)  \
# ...

# %%
from IPython.display import Image, display

display(Image(filename='question_text.png', width=400))

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Summary values
total_responses = len(df_duo)
yes_count = df_duo['uses_duo'].value_counts().get('Yes', 0)
no_count = df_duo['uses_duo'].value_counts().get('No', 0)
free_count = df_duo['free_or_premium'].value_counts().get('Free Version', 0)
premium_count = df_duo['free_or_premium'].value_counts().get('Premium Duolingo', 0)
nan_count = df_duo['free_or_premium'].isna().sum()

# Create a summary table
summary_df = pd.DataFrame({
    'Category': ['Total Responses', 'Yes (Uses Duolingo)', 'No (Doesn’t Use)', 
                 'Free Version Users', 'Premium Users',],
    'Count': [total_responses, yes_count, no_count, free_count, premium_count]
})

summary_df
# Out:
#               Category  Count
# 0      Total Responses    120
# 1  Yes (Uses Duolingo)     94
# 2     No (Doesn’t Use)     26
# 3   Free Version Users     80
# 4        Premium Users     14

# %%
# Limiting data analysis from here on to users that have said:
#     1. "Yes" to uses_duo &
#     2. "Free Version" to free_or_premium
df_duo_free = df_duo[
    (df_duo['uses_duo'] == 'Yes') &
    (df_duo['free_or_premium'] == 'Free Version')
].reset_index(drop=True)

# %% [markdown]
# ## PHASE 1: BASIC EXPLORATION (FOUNDATIONAL EDA)

# %% [markdown]
# ##### DEMOGRAPHIC ANALYSIS

# %%
# Replace "18 almost 19" entry with 18
df_duo_free['age'] = df_duo_free['age'].replace('18 almost 19', 18)
# Then safely convert the column to integers
df_duo_free['age'] = df_duo_free['age'].astype(float)

# Drop missing or invalid age values, just in case
ages = df_duo_free['age'].dropna().astype(int)

plt.figure(figsize=(8, 5))
plt.hist(ages, bins=10, edgecolor='black', color='#58cc02')
plt.title('Age Distribution of Free Duolingo Users')
plt.xlabel('Age')
plt.ylabel('Number of Respondents')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Replace NaN in 'fluent_lang_num' with '3 or more'
df_duo_free['fluent_lang_num_filled'] = df_duo_free['fluent_lang_num'].fillna('3 or more')

# Convert any numeric-looking values to string for consistency
df_duo_free['fluent_lang_num_filled'] = df_duo_free['fluent_lang_num_filled'].replace({
    1.0: '1',
    2.0: '2',
    1: '1',
    2: '2',
    3: '3 or more',
    3.0: '3 or more'
})

# Count and order
fluent_counts = df_duo_free['fluent_lang_num_filled'].value_counts().reindex(['1', '2', '3 or more'])

# Plot

plt.figure(figsize=(8, 5))
fluent_counts.plot(kind='bar', color='#58cc02', edgecolor='black')

plt.title('Number of Fluent Languages Spoken by Users')
plt.xlabel('Fluent Languages')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ##### USAGE PATTERN ANALYSIS

# %%
# Map long responses to numeric codes
frequency_map = {
    "Rarely": "1",
    "A few times a month": "2",
    "A few times a week": "3",
    "Daily": "4",
    "I have used it before but I don't use it anymore": "5"
}

# Apply mapping
df_duo_free['frequency_mapped'] = df_duo_free['frequency'].map(frequency_map)

# Count
frequency_counts = df_duo_free['frequency_mapped'].value_counts().reindex(['1', '2', '3', '4', '5'])

# Create reverse mapping for legend
legend_text = '\n'.join([
    f"{num}: {label}" for label, num in frequency_map.items()
])

# Plot
import matplotlib.pyplot as plt

plt.figure(figsize=(9, 5))
frequency_counts.plot(kind='bar', color='#58cc02', edgecolor='black')

plt.title('How Often Users Use Free Duolingo')
plt.xlabel('Usage Frequency')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add legend as text box
plt.text(
    5.3,  # x-position (adjust if needed)
    max(frequency_counts) * 0.9,  # y-position
    legend_text,
    fontsize=10,
    bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5')
)

plt.tight_layout()
plt.show()

# %%
consistency_map = {
    "Less than 1 month": "1",
    "1-6 months": "2",
    "6-12 months": "3",
    "Over a year": "4",
    "I used to use it consistently but not at the moment": "5"
}

# Apply mapping
df_duo_free['consistency_mapped'] = df_duo_free['consistency'].map(consistency_map)

# Count in correct order
consistency_counts = df_duo_free['consistency_mapped'].value_counts().reindex(['1', '2', '3', '4', '5'])

# Reverse mapping for legend text
legend_text = '\n'.join([f"{num}: {label}" for label, num in consistency_map.items()])

# Plot
import matplotlib.pyplot as plt

plt.figure(figsize=(9, 5))
consistency_counts.plot(kind='bar', color='#58cc02', edgecolor='black')

plt.title('How Long Users Have Been Using Duolingo')
plt.xlabel('Duration of Use')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add legend box
plt.text(
    5.3,
    max(consistency_counts) * 0.9,
    legend_text,
    fontsize=10,
    bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5')
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### MOTIVATION ANALYSIS

# %%
# Drop NaN responses
reason_series = df_duo_free['reason'].dropna()

# Step 1: Flatten all comma-separated entries
all_reasons = []
for entry in reason_series:
    parts = [r.strip() for r in entry.split(',')]  # split & remove extra spaces
    all_reasons.extend(parts)

# Step 2: Count frequency of each individual reason
reason_counts = Counter(all_reasons)

# Step 3: Convert to DataFrame for plotting
reason_df = pd.DataFrame(reason_counts.items(), columns=['Reason', 'Count']).sort_values(by='Count', ascending=False)

# Step 4: Plot
plt.figure(figsize=(9, 5))
plt.bar(reason_df['Reason'], reason_df['Count'], color='#58cc02', edgecolor='black')
plt.title('Motivations for Using Free Duolingo')
plt.xlabel('Reason')
plt.ylabel('Number of Mentions')
plt.xticks(rotation=25, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## PHASE 2: CURRENT DUOLINGO PERSONALIZATION EXPLORATION

# %% [markdown]
# ##### PERCEIVED PERSONALIZATION: adapt_individual

# %%
# Optional: set logical order
adapt_order = [
    "Yes, it adjusts well to my progress and mistakes",
    "Somewhat, but it still feels repetitive/generic at times",
    "No, it feels like a one-size-fits-all experience"
]

# Count + order
adapt_counts = df_duo_free['adapt_individual'].value_counts().reindex(adapt_order)

# Plot
plt.figure(figsize=(10, 5))
adapt_counts.plot(kind='bar', color='#58cc02', edgecolor='black')

plt.title("How Well Does Duolingo Adapt to Users' Individual Learning Styles?")
plt.xlabel('Perceived Adaptation')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=15, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
df_duo_free['adapt_mistakes'].value_counts()
# Out:
# adapt_mistakes
# Somewhat – it repeats exercises but doesn’t provide deeper explanations        54
# Poorly – it keeps making me redo the same thing without additional guidance    14
# Very well – it gives targeted explanations and reviews                         12
# Name: count, dtype: int64

# %% [markdown]
# ##### PERCEIVED PERSONALIZATION: adapt_mistakes

# %%
# Manual order for clean storytelling
mistake_order = [
    "Very well – it gives targeted explanations and reviews",
    "Somewhat – it repeats exercises but doesn’t provide deeper explanations",
    "Poorly – it keeps making me redo the same thing without additional guidance"
]

mistake_counts = df_duo_free['adapt_mistakes'].value_counts().reindex(mistake_order)

# Plot
import matplotlib.pyplot as plt

plt.figure(figsize=(11, 5))
mistake_counts.plot(kind='bar', color='#58cc02', edgecolor='black')

plt.title("How Well Does Duolingo Help Users After Making Mistakes?")
plt.xlabel('Perceived Support')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=10, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### PERCEIVED PERSONALIZATION: adapt_effectiveness

# %%
# Clean and convert to numeric just in case
df_duo_free['adapt_effectiveness'] = pd.to_numeric(df_duo_free['adapt_effectiveness'], errors='coerce')

# Count discrete values
effectiveness_counts = df_duo_free['adapt_effectiveness'].value_counts().reindex([1, 2, 3, 4, 5])

# Plot as a bar chart
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
effectiveness_counts.plot(kind='bar', color='#58cc02', edgecolor='black')

plt.title("Perceived Effectiveness of Duolingo's Personalization Features")
plt.xlabel('Effectiveness Rating (1 = Low, 5 = High)')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### PERCEIVED PERSONALIZATION: best_feature

# %%
import re
from collections import Counter
import matplotlib.pyplot as plt

# Drop NaNs
feature_series = df_duo_free['best_feature'].dropna()

# Use regex to split only on commas outside parentheses
def smart_split(text):
    return re.split(r',\s*(?![^(]*\))', text)

# Flatten all entries
all_features = []
for entry in feature_series:
    parts = [f.strip() for f in smart_split(entry)]
    all_features.extend(parts)

# Count frequencies
feature_counts = Counter(all_features)
total_responses = len(feature_series)

# Convert to percentages
feature_df = pd.DataFrame({
    'Feature': list(feature_counts.keys()),
    'Percent': [round((count / total_responses) * 100, 1) for count in feature_counts.values()]
}).sort_values(by='Percent', ascending=False)

# Plot
plt.figure(figsize=(10, 5))
plt.bar(feature_df['Feature'], feature_df['Percent'], color='#58cc02', edgecolor='black')
plt.title("Most Helpful Duolingo Features (as % of Respondents)")
plt.xlabel('Feature')
plt.ylabel('Percentage of Respondents (%)')
plt.xticks(rotation=25, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## PHASE 3: IDENTIFYING USER PAIN POINTS & POTENTIAL SOLUTIONS

# %% [markdown]
# ##### USER PAIN POINTS

# %%
# Original options (exact phrasing from your survey)
pain_options = [
    "Repetitive exercises with no real explanations",
    "Lack of real-world context in sentence examples",
    "Weak pronunciation and speech feedback",
    "Lessons feel too rigid, not adapted to my learning style",
    "Other:"
]

# Create a function to check which options are in each entry
all_matched_pain_points = []

for entry in df_duo_free['pain_point'].dropna():
    matched = [option for option in pain_options if option in entry]
    all_matched_pain_points.extend(matched)

# Count matches
from collections import Counter
pain_counts = Counter(all_matched_pain_points)
total_respondents = len(df_duo_free['pain_point'].dropna())

# To DataFrame with %
pain_df = pd.DataFrame({
    'Pain Point': list(pain_counts.keys()),
    'Percent': [round((count / total_respondents) * 100, 1) for count in pain_counts.values()]
}).sort_values(by='Percent', ascending=False)

# Plot
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.bar(pain_df['Pain Point'], pain_df['Percent'], color='#58cc02', edgecolor='black')
plt.title("Main Pain Points with Free Duolingo (as % of Respondents)")
plt.xlabel('Pain Point')
plt.ylabel('Percentage of Respondents (%)')
plt.xticks(rotation=25, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Corrected full options
improvement_options = [
    "AI-generated video explanations for tricky grammar concepts",
    "More real-world sentence examples related to my interests",
    "Personalized pronunciation feedback that adapts to my accent",
    "A smarter review system that focuses on my specific weakness",
    "Other"
]

# Match responses
all_matched_improvements = []

for entry in df_duo_free['potential_improvement'].dropna():
    matched = [option for option in improvement_options if option in entry]
    all_matched_improvements.extend(matched)

# Count matches
from collections import Counter
improvement_counts = Counter(all_matched_improvements)
total_respondents = len(df_duo_free['potential_improvement'].dropna())

# Short labels mapping (including Other)
label_mapping = {
    "AI-generated video explanations for tricky grammar concepts": "AI-generated videos",
    "More real-world sentence examples related to my interests": "Adaptive sentences",
    "Personalized pronunciation feedback that adapts to my accent": "Personalized pronunciation",
    "A smarter review system that focuses on my specific weakness": "Smarter review system",
    "Other": "Other"
}

# Build dataframe with short labels
import pandas as pd
improvement_df = pd.DataFrame({
    'Full': list(improvement_counts.keys()),
    'Percent': [round((count / total_respondents) * 100, 1) for count in improvement_counts.values()]
})
improvement_df['Short'] = improvement_df['Full'].map(label_mapping)

# Reorder bars (Other goes last)
ordered_labels = [
    "AI-generated videos",
    "Adaptive sentences",
    "Personalized pronunciation",
    "Smarter review system",
    "Other"
]
improvement_df = improvement_df.set_index('Short').reindex(ordered_labels).reset_index()

# Plot
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.bar(improvement_df['Short'], improvement_df['Percent'], color='#58cc02', edgecolor='black')
plt.title("Top Feature Requests for Duolingo (as % of Respondents)")
plt.xlabel('Feature Request')
plt.ylabel('Percentage of Respondents (%)')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# 📝 Print legend
print("Legend:\n")
print("AI-generated videos: AI-generated video explanations for tricky grammar concepts")
print("Adaptive sentences: More real-world sentence examples related to my interests")
print("Personalized pronunciation: Personalized pronunciation feedback that adapts to my accent")
print("Smarter review system: A smarter review system that focuses on my specific weakness")
print("Other: User wrote in a custom suggestion not listed in predefined options")
# Out:
# Legend:
#
# AI-generated videos: AI-generated video explanations for tricky grammar concepts
# Adaptive sentences: More real-world sentence examples related to my interests
# Personalized pronunciation: Personalized pronunciation feedback that adapts to my accent
# Smarter review system: A smarter review system that focuses on my specific weakness
# Other: User wrote in a custom suggestion not listed in predefined options

# %% [markdown]
# ### NOTE(to self, delete later):
# UI feedback was largely neutral or positive, with most respondents either leaving this section blank or expressing satisfaction with the current interface
